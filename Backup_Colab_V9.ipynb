# %% [markdown]
# <a href="https://colab.research.google.com/github/cdkfox/remocolab/blob/master/Backup_Colab_V9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# Unblock Websites
# !sudo echo "nameserver 1.1.1.1" > /etc/resolv.conf

# APT update
# !sudo rm -f /etc/apt/sources.list
# !sudo wget "https://raw.githubusercontent.com/cdkfox/remocolab/master/sources.list" -O /etc/apt/sources.list
# !sudo apt update

# Stop ngrok processes
# !sudo pkill -f ngrok

# Official NGROK Tunnel
# !pip install git+https://github.com/demotomohiro/remocolab.git
import remocolab
remocolab.setupVNC(ngrok_region="jp")
# Out:
# Mounted at /content/drive
# --2020-04-28 09:02:05--  https://raw.githubusercontent.com/cdkfox/remocolab/master/sources.list
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.128.133, 151.101.192.133, 151.101.64.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.128.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2830 (2.8K) [text/plain]
# Saving to: ‘/etc/apt/sources.list’
#
# /etc/apt/sources.li 100%[===================>]   2.76K  --.-KB/s    in 0s
#
# 2020-04-28 09:02:06 (48.0 MB/s) - ‘/etc/apt/sources.list’ saved [2830/2830]
#
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# ...

# %%
import subprocess

# Install Essential Softwares
# !sudo apt-get install -y fonts-wqy-microhei
# !sudo apt-get install -y htop
# !sudo apt-get install -y firefox chromium-browser
# !sudo wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !sudo apt install ./google-chrome-stable_current_amd64.deb
# !sudo apt install aria2 -y
# !sudo apt install xrdp && sudo apt install xorg && sudo adduser xrdp ssl-cert
# !sudo apt install xarchiver pcmanfm -y



# Switch from plain SSH to Shadowsocks-libev + V2ray-plugin
# !sudo apt install shadowsocks-libev
# !sudo pkill -f ngrok
# !sudo pkill -f ss-server
# !sudo wget "https://github.com/shadowsocks/v2ray-plugin/releases/download/v1.3.0/v2ray-plugin-linux-amd64-v1.3.0.tar.gz" -O v2ray-plugin.tar.gz
# !sudo tar -xvf v2ray-plugin.tar.gz
# !sudo mv v2ray-plugin_linux_amd64 v2ray-plugin
# !sudo mv v2ray-plugin /usr/bin/
front_proc = subprocess.Popen(["ss-server", "--fast-open", "--no-delay", "-s", "0.0.0.0", "-p", "2337", "-k", "google-colab", "-m", "chacha20-ietf-poly1305", "--plugin", "v2ray-plugin", "--plugin-opts", "server;fast-open;host=www.baidu.com"])
# Expose ss 2337, you can connect via SSH@localhost
ngrok_proc = subprocess.Popen(["/content/ngrok", "tcp", "-region", "jp", "2337"])
print("Copy&paste your tunnel port number from https://dashboard.ngrok.com/status/tunnels")
# Start XRDP
xrdp_sesman_proc = subprocess.Popen(["xrdp-sesman", "-n"])
xrdp_proc = subprocess.Popen(["xrdp", "-n"])
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-wqy-microhei
# 0 upgraded, 1 newly installed, 0 to remove and 21 not upgraded.
# Need to get 1,607 kB of archives.
# After this operation, 5,257 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-wqy-microhei all 0.2.0-beta-3 [1,607 kB]
# Fetched 1,607 kB in 2s (675 kB/s)
# dpkg-preconfigure: unable to re-open stdin: No such file or directory
# Selecting previously unselected package fonts-wqy-microhei.
# (Reading database ... 178658 files and directories currently installed.)
# Preparing to unpack .../fonts-wqy-microhei_0.2.0-beta-3_all.deb ...
# Unpacking fonts-wqy-microhei (0.2.0-beta-3) ...
# Setting up fonts-wqy-microhei (0.2.0-beta-3) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Reading package lists... Done
# Building dependency tree
# ...

# %% [markdown]
# # Configure Docker Enabled Cloud Shell
#
# # IMPORTANT:
# * Do not use v2ray mux
# * Balance the ngrok traffic through different ips provided by dnslookup.online
# * Use the JP NGROK
# * Use TurboVNC and MSTSC
# * Login Using Root Credentials
# * Use the Bitvise SSH Client with automatic reconnection
# * Resolve DNS over SOCKS5 PROXY.
# * Reduce mstsc quality to minimum.
# * Enable and Setup Windows Firewall to only allow ss TCP 2333 + 2334
# * Explore Oreilly, Packt, PluralSight and Yahoo Finance While Setting Up.
# * Enable DMZ mode for home routers
# * Use 2 node (apv4+apv6) and High Avilability Mode on Layer 3 ss
# * Host is not colab@*.*.* which is the host+username
# * Use 3 Layer distributor with telegram mtproxy
# * Use Hostfile editor with DNSCrypt-Proxy
# * Set distributor's out system proxy status to disabled and severs to High Availability
# * Use gfwlist with switchomega
#
#
# 1. Change `root` and `colab` passwords
# ```zsh
# sudo su
# ```
# ```zsh
# passwd root
# ```
# ```zsh
# passwd colab
# ```
#
# 2. Start Chrome - root
# ```zsh
# google-chrome --no-sandbox &!
# google-chrome --no-sandbox --disable-gpu &!
# chromium-browser --no-sandbox &!
# ```
#
# 3. Code Server - root
# ```zsh
# su root
# ```
# ```zsh
# rm -rf ~/code-server-release/
# cd ~/
# sudo aria2c "https://github.com/cdr/code-server/releases/download/3.1.1/code-server-3.1.1-linux-x86_64.tar.gz" -o code-server-release.tar.gz
# sudo mkdir code-server-release/
# sudo tar -xf code-server-release.tar.gz --directory code-server-release/
# cd ~/code-server-release/
# cd ~/code-server-release/*/
# sudo openssl genrsa 2048 > vscode.key
# sudo chmod 400 vscode.key
# sudo openssl req -new -x509 -nodes -sha256 -days 365 -key vscode.key -out vscode.cert
# ```
# ```zsh
# sudo ./code-server --port 8081 --auth none --cert vscode.cert --cert-key vscode.key &!
# ```
#
# 4. Set Uncensored DNS - root
# ```zsh
# rm -f /etc/resolv.conf
# cat << EOF | tee !$
# nameserver 1.1.1.1
# nameserver 1.1.1.1
# nameserver 9.9.9.9
# EOF
# ```
#
# 5. Run Cloud Torrents & Coding - root
# ```zsh
# sudo curl https://i.jpillora.com/cloud-torrent! | bash
# sudo /usr/local/bin/cloud-torrent &!
# ```
#
#
# # Keep SSH Connection Alive
# ```zsh
# cat << EOF | tee ~/.ssh/config
# Host 0.tcp.ngrok.io
#     Hostname 0.tcp.ngrok.io
#     Port 10975
#     User colab
#     ServerAliveInterval 3
#     ServerAliveCountMax 200
# EOF
# cat ~/.ssh/config
# ```
#
# # Local - Delete the old `known_hosts`
# ```zsh
# rm -f ~/.ssh/known_hosts
# ```
#
# # Local - Change the port and address, Connect using ngrok, local computer port is listed as follows
# * VNC - 5901
# * XRDP - 3390
# * CODE-HTTPS - 8081
# * Whatever - 10000
# * Whatever2 - 10001
# * bay-downloads - 3000
#
# # Local - The unstable way - SSH - C2S
# ```zsh
# ssh -o UserKnownHostsFile=/dev/null -o VisualHostKey=yes
# -L 3000:localhost:3000
# -L 5901:localhost:5901
# -L 8081:localhost:8081
# -L 10000:localhost:10000
# -L 10001:localhost:10001
# -L 3390:localhost:3389
# -p 19024 colab@0.tcp.ngrok.io
# ```
#
# # Gen SSH Keypairs - root
# ```zsh
# ssh-keygen && \
# cat /root/.ssh/id_rsa.pub
# ```
#
# # Gen SSH Keypairs - colab
# ```zsh
# ssh-keygen && \
# cat /home/colab/.ssh/id_rsa.pub
# ```
#
# # Install OhMyZsh - colab
# ```zsh
# su colab
# ```
# ```zsh
# apt install zsh -y
# sh -c "$(curl -fsSL https://raw.githubusercontent.com/ohmyzsh/ohmyzsh/master/tools/install.sh)"
# ```
#
# # Switch to Google Drive Directory
# ```zsh
# cd /content/drive/My\ Drive/Downloads/downloads
# ```
#
# # Sync Google Chrome Account
# # Sync Coding SSH Public Key
#
# # Upload Downloaded Files
# ```zsh
# git add .
# git config --global user.email "nobody@nobody.com"
# git config --global user.name "nobody"
# git commit -m "initial commit"
# git push -u origin master
# ```
#
# # High Memory Instance
# ```py
# a = []
# while(1):
#   a.append('1')
# ```
